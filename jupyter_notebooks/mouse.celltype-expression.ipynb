# %%
import numpy as np
import pandas as pd
import glob

# %%
# Import Barres celltype enrichment raw data
raw_df = pd.read_excel('../data/barreslab_rnaseq.xlsx',sheet_name='Raw Data',index_col='Gene symbol')

# %%
# Define each gene's expression level in oligodendrocyte as the average of three cell types
raw_df['Oligodendrocyte']=raw_df.loc[:,'Oligodendrocyte Precursor Cell':'Myelinating Oligodendrocytes'].mean(axis=1)

# %%
# Clean up table
raw_df.drop(['Description','Oligodendrocyte Precursor Cell','Newly Formed Oligodendrocyte','Myelinating Oligodendrocytes'],axis=1,inplace=True)

# %%
raw_df = raw_df.reindex(columns=['Neuron','Endothelial Cells', 'Oligodendrocyte', 'Astrocytes', 'Microglia'])

# %%
# Glial cell expression level as average expression level of oligodendrocyte, astrocyte, and microglia
raw_df['Glial Cells']=raw_df.loc[:,'Oligodendrocyte':'Microglia'].mean(axis=1)

# %%
raw_df
# Out:
#                   Neuron  Endothelial Cells  Oligodendrocyte  Astrocytes  \
# Gene symbol
# 0610005C13Rik   0.100000           0.100000         0.100000    0.150958
# 0610007C21Rik  34.185493          63.561109        61.071109   44.891260
# 0610007L01Rik  12.028727          13.521373        11.161263   11.015039
# 0610007P08Rik   2.020408           4.693264         4.455001    7.144110
# 0610007P14Rik  24.370482          10.569456        62.335636   48.935666
# ...                  ...                ...              ...         ...
# Zyg11a          0.100000           0.100000         0.100000    0.100000
# Zyg11b         14.748427           7.883384         5.880200    7.196140
# Zyx            12.732356          35.416643        17.037024   12.443373
# Zzef1           4.842996           4.443834         4.460314    9.346480
# Zzz3            5.624916           7.543416         6.111705    7.886449
#
#                Microglia  Glial Cells
# Gene symbol
# 0610005C13Rik   0.100000     0.116986
# 0610007C21Rik  89.145033    65.035801
# 0610007L01Rik  18.462419    13.546240
# 0610007P08Rik   0.446900     4.015337
# 0610007P14Rik  10.411304    40.560869
# ...                  ...          ...
# Zyg11a          0.100000     0.100000
# Zyg11b          2.513958     5.196766
# Zyx            74.185894    34.555430
# Zzef1           2.433903     5.413566
# Zzz3            1.621927     5.206694
#
# [22458 rows x 6 columns]

# %%
raw_df.to_csv('../results/mouse.celltype-expression.tsv',sep='\t',header=True)
