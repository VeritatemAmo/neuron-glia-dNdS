# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# %%
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300

# %%
hPSD_df=pd.read_csv('../results/Bayes_et_al_2011/neuronal_hPSD.mouse_ortholog_of_human.txt',sep='\t')

# %%
hPSD_set = set(hPSD_df[hPSD_df['Mouse homology type']=='ortholog_one2one']['Mouse gene stable ID'])

# %%
non_hPSD_df=pd.read_csv('../results/Bayes_et_al_2011/neuronal_non-hPSD.mouse_ortholog_of_human.txt',sep='\t')

# %%
non_hPSD_set=set(non_hPSD_df[non_hPSD_df['Mouse homology type']=='ortholog_one2one']['Mouse gene stable ID'])

# %%
mouse_neuron_df=pd.read_csv('../results/mouse.celltype-specific_genes/protein-coding_w_dNdS/Ensembl_ID_neuron.tsv',sep='\t',names=['Mouse gene stable ID'])

# %%
mouse_neuron_set=set(mouse_neuron_df['Mouse gene stable ID'])

# %%
venn3([mouse_neuron_set,hPSD_set,non_hPSD_set],set_labels=('Mouse Neuron-sp','Neuronal hPSD','Neuronal non hPSD'))
